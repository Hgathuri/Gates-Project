# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pptx import Presentation
import pptx

# %%
df = pd.read_csv("C:\\Users\hgathuri\Desktop\CO\Data\Gates3.csv")

# %%
df.shape
# Out:
# (69, 250)

# %%
df.columns
# Out:
# Index(['record_id', 'redcap_survey_identifier',
#        'covid19_modelling_survey_timestamp', 'language', 'consent', 'q1', 'q2',
#        'q3', 'country', 'q4___1',
#        ...
#        'q12_sp___5', 'q12_sp___6', 'q12_sp___7', 'q12_other_specify_sp',
#        'q13_sp', 'ways_for_engagement_sp___1', 'ways_for_engagement_sp___2',
#        'ways_for_engagement_sp___3', 'email',
#        'covid19_modelling_survey_complete'],
#       dtype='object', length=250)

# %%
df.head()
# Out:
#    record_id  redcap_survey_identifier covid19_modelling_survey_timestamp  \
# 0          1                       NaN                     5/6/2022 18:11
# 1          2                       NaN                     5/6/2022 18:12
# 2          3                       NaN                     5/6/2022 18:20
# 3          4                       NaN                     5/6/2022 18:28
# 4          5                       NaN                     5/6/2022 19:46
#
#   language                              consent    q1         q2  \
# 0  English  I agree, continue the investigation  Male  45 - 54yr
# 1  English  I agree, continue the investigation  Male  35 - 44yr
# 2  English  I agree, continue the investigation  Male  25 - 34yr
# 3  Spanish                                  NaN   NaN        NaN
# 4  English  I agree, continue the investigation  Male  45 - 54yr
#
#                       q3         country     q4___1  ... q12_sp___5  \
# ...

# %%
df['language'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
l = df['language'].value_counts(sort=False).reset_index()
dfl = pd.DataFrame(l, columns=['index','language'])
dfl['lang_pct'] = round(((dfl['language'] / dfl['language'].sum()) * 100),2)
dfl = dfl.set_index('index')
dfl
# Out:
#          language  lang_pct
# index
# English        60     86.96
# Spanish         7     10.14
# French          2      2.90

# %%
bx = dfl['lang_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Language preference to taking the survey ", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion of Respondents (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('Language.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q1'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
g = df['q1'].value_counts(sort=False).reset_index()
dfg = pd.DataFrame(g, columns=['index','q1'])
dfg['lang_pct'] = round(((dfg['q1'] / dfg['q1'].sum()) * 100),2)
dfg = dfg.set_index('index')
dfg
# Out:
#         q1  lang_pct
# index
# Male    32     53.33
# Female  27     45.00
# Other    1      1.67

# %%
bx = dfg['lang_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Gender of the respondents", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q1.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q2'].value_counts(sort=False)
# Out:
# 45 - 54yr    20
# 35 - 44yr    23
# 25 - 34yr    11
# ≥65yr         1
# 55 - 64yr     5
# Name: q2, dtype: int64

# %%
a = df['q2'].value_counts().reset_index()
df1 = pd.DataFrame(a, columns=['index','q2'])

# %%
df1
# Out:
#        index  q2
# 0  35 - 44yr  23
# 1  45 - 54yr  20
# 2  25 - 34yr  11
# 3  55 - 64yr   5
# 4      ≥65yr   1

# %%
df1['q2_pct'] = round(((df1['q2'] / df1['q2'].sum()) * 100),2)

# %%
df1['q2_pct']
# Out:
# 0    38.33
# 1    33.33
# 2    18.33
# 3     8.33
# 4     1.67
# Name: q2_pct, dtype: float64

# %%
df1 = df1.set_index('index')

# %%
df1
# Out:
#            q2  q2_pct
# index
# 35 - 44yr  23   38.33
# 45 - 54yr  20   33.33
# 25 - 34yr  11   18.33
# 55 - 64yr   5    8.33
# ≥65yr       1    1.67

# %%
bx = df1['q2_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Age groups of the respondents", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q2.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q3'].value_counts(sort=False)
# Out:
# Europe                   13
# Africa                   29
# Central/South America     3
# South East Asia           9
# Western Pacific           1
# North America             4
# Eastern Mediterranean     1
# Name: q3, dtype: int64

# %%
c = df['q3'].value_counts(sort=False).reset_index()
df3 = pd.DataFrame(c, columns=['index','q3'])
df3['q3_pct'] = round(((df3['q3'] / df3['q3'].sum()) * 100),2)
df3 = df3.set_index('index')

# %%
bx = df3['q3_pct'].plot(kind='barh',figsize=(20,10))


#add overall title
plt.title("Respondents' region of work", fontsize=24)

#add axis titles
plt.ylabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
#plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(width), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q3.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q5'].value_counts()
# Out:
# < 5yr        20
# 5 - 10 yr    16
# 11 - 14yr    11
# 15 - 20yr     8
# > 20yr        5
# Name: q5, dtype: int64

# %%
e = df['q5'].value_counts().reset_index()
df5 = pd.DataFrame(e, columns=['index','q5'])
df5['q5_pct'] = round(((df5['q5'] / df5['q5'].sum()) * 100),2)
df5 = df5.set_index('index')

# %%
bx = df5['q5_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Time spent in the current role", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q5.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q4___1'].value_counts()
# Out:
# Checked      49
# Unchecked    20
# Name: q4___1, dtype: int64

# %%
df['q4___2'].value_counts()
# Out:
# Unchecked    62
# Checked       7
# Name: q4___2, dtype: int64

# %%
df['q4___3'].value_counts()
# Out:
# Unchecked    54
# Checked      15
# Name: q4___3, dtype: int64

# %%
data = [["Researcher/modeler", 47], ["Policymaker (national/international)", 7], ["Policy Advisor (local/international)", 15]]
 
# Create the pandas DataFrame
df4 = pd.DataFrame(data, columns=['Role', 'Number'])

# %%
df4
# Out:
#                                    Role  Number
# 0                    Researcher/modeler      47
# 1  Policymaker (national/international)       7
# 2  Policy Advisor (local/international)      15

# %%
df4['q4_pct'] = round(((df4['Number'] / df4['Number'].sum()) * 100),2)
df4 = df4.set_index('Role')

# %%
df4
# Out:
#                                       Number  q4_pct
# Role
# Researcher/modeler                        47   68.12
# Policymaker (national/international)       7   10.14
# Policy Advisor (local/international)      15   21.74

# %%
bx = df4['q4_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Professional roles that respondents play", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q4.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
#Researcher/modeler
r = df.loc[df['q4___1']=='Checked']
#r = r['q5'].value_counts().reset_index()
r['role'] = "Researcher/modeler"
r
# Out:
# C:\Users\hgathuri\AppData\Local\Temp\ipykernel_22052\3724020191.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   r['role'] = "Researcher/modeler"
#     record_id  redcap_survey_identifier covid19_modelling_survey_timestamp  \
# 0           1                       NaN                     5/6/2022 18:11
# 1           2                       NaN                     5/6/2022 18:12
# 2           3                       NaN                     5/6/2022 18:20
# 4           5                       NaN                     5/6/2022 19:46
# 6           7                       NaN                      5/7/2022 3:53
# 7           8                       NaN                      5/7/2022 7:47
# ...

# %%
#Policymaker (national/international)
p = df.loc[df['q4___2']=='Checked']
#p = p['q5'].value_counts().reset_index()
p['role'] = "Policymaker (national/international)"
p
# Out:
# C:\Users\hgathuri\AppData\Local\Temp\ipykernel_22052\2604531734.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p['role'] = "Policymaker (national/international)"
#     record_id  redcap_survey_identifier covid19_modelling_survey_timestamp  \
# 7           8                       NaN                      5/7/2022 7:47
# 9          10                       NaN                     5/8/2022 17:26
# 12         13                       NaN                     5/9/2022 14:52
# 53         56                       NaN                     6/6/2022 11:43
# 55         58                       NaN                     6/6/2022 12:39
# 56         59                       NaN                     6/6/2022 13:33
# ...

# %%
#Policy Advisor (local/international)
pa = df.loc[df['q4___3']=='Checked']
#pa = pa['q5'].value_counts().reset_index()
pa['role'] = "Policy Advisor (local/international)"
pa
# Out:
# C:\Users\hgathuri\AppData\Local\Temp\ipykernel_22052\2215124060.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pa['role'] = "Policy Advisor (local/international)"
#     record_id  redcap_survey_identifier covid19_modelling_survey_timestamp  \
# 7           8                       NaN                      5/7/2022 7:47
# 26         29                       NaN                    5/13/2022 15:41
# 31         34                       NaN                    5/16/2022 11:53
# 32         35                       NaN                    5/16/2022 16:45
# 34         37                       NaN                    5/20/2022 12:53
# 37         40                       NaN                    [not completed]
# ...

# %%
time_in_roles = pd.concat([r,p,pa])
time_in_roles
# Out:
#     record_id  redcap_survey_identifier covid19_modelling_survey_timestamp  \
# 0           1                       NaN                     5/6/2022 18:11
# 1           2                       NaN                     5/6/2022 18:12
# 2           3                       NaN                     5/6/2022 18:20
# 4           5                       NaN                     5/6/2022 19:46
# 6           7                       NaN                      5/7/2022 3:53
# ..        ...                       ...                                ...
# 48         51                       NaN                    5/31/2022 22:12
# 57         60                       NaN                     6/7/2022 21:20
# 60         63                       NaN                    6/13/2022 17:47
# 63         66                       NaN                    [not completed]
# 67         70                       NaN                    6/16/2022 15:01
#
# ...

# %%
time_in_roles = time_in_roles.rename(columns={'q5':'time_spent'})
time_in_roles.groupby(['role','time_spent'])['q1'].count().plot(kind='bar',stacked=True, figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='role,time_spent'>

# %%
bx2 = pd.crosstab(time_in_roles['role'], time_in_roles["time_spent"]).plot\
(kind='bar',stacked=False,title='Timely Repayment Percentage of Products bought',figsize=(20,10))


#add overall title
plt.title("Time Spent in the respective roles that respondents play", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Count",fontsize=20)
plt.yticks(fontsize=20)

for q in bx2.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q4_2.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q6'].value_counts()
# Out:
# Yes    44
# No      5
# Name: q6, dtype: int64

# %%
f = df['q6'].value_counts().reset_index()
df6 = pd.DataFrame(f, columns=['index','q6'])
df6['q6_pct'] = round(((df6['q6'] / df6['q6'].sum()) * 100),2)
df6 = df6.set_index('index')

# %%
bx = df6['q6_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Researchers’ experience sharing COVID-19 modeling data outputs with policy decision makers/advisors", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q6.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q7a___1'].value_counts()
# Out:
# Checked      36
# Unchecked    33
# Name: q7a___1, dtype: int64

# %%
df['q7a___2'].value_counts()
# Out:
# Unchecked    41
# Checked      28
# Name: q7a___2, dtype: int64

# %%
df['q7a___3'].value_counts()
# Out:
# Unchecked    45
# Checked      24
# Name: q7a___3, dtype: int64

# %%
df['q7a___4'].value_counts()
# Out:
# Unchecked    40
# Checked      29
# Name: q7a___4, dtype: int64

# %%
data7 = [["The policy makers/advisors requested COVID-19 modeling data from you/your group to guide their decision making during the pandemic", 36], 
         ["You/your group presented COVID-19 modeling data to policy makers/advisors (unsolicited)", 28], 
         ["You/your group have a pre-existing working relationship with policy makers/advisors and have been working together to create policy questions and generate evidence for decision-making prior to the pandemic", 24],
         ["You/your group developed a new working relationship with policy makers/advisors during the pandemic and are now working together to create policy questions and generate evidence for decision-making", 29]]
 
# Create the pandas DataFrame
df7 = pd.DataFrame(data7, columns=['Prb', 'q7'])

# %%
df7
# Out:
#                                                  Prb  q7
# 0  The policy makers/advisors requested COVID-19 ...  36
# 1  You/your group presented COVID-19 modeling dat...  28
# 2  You/your group have a pre-existing working rel...  24
# 3  You/your group developed a new working relatio...  29

# %%
df7.to_csv('q7.csv')

# %%
df7['q7_pct'] = round(((df7['q7'] / df7['q7'].sum()) * 100),2)
df7 = df7.set_index('Prb')

# %%
bx = df7['q7_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Problem identification, knowledge research/development (Researchers/ Modelers) ", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=45)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
import textwrap
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0)

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q7.png',dpi=400, bbox_inches="tight")

# %%
df['q7b___1'].value_counts()
# Out:
# Unchecked    35
# Checked      34
# Name: q7b___1, dtype: int64

# %%
df['q7b___2'].value_counts()
# Out:
# Unchecked    64
# Checked       5
# Name: q7b___2, dtype: int64

# %%
df['q7b___3'].value_counts()
# Out:
# Unchecked    58
# Checked      11
# Name: q7b___3, dtype: int64

# %%
df['q7b___4'].value_counts()
# Out:
# Unchecked    40
# Checked      29
# Name: q7b___4, dtype: int64

# %%
df['q7b___5'].value_counts()
# Out:
# Unchecked    63
# Checked       6
# Name: q7b___5, dtype: int64

# %%
df['q7b___6'].value_counts()
# Out:
# Unchecked    41
# Checked      28
# Name: q7b___6, dtype: int64

# %%
data7b = [["My/our group COVID-19 modeling reports were read and understood by policy makers/advisors (you received feedback from them)", 34], 
         ["My/our group COVID-19 modeling reports were not read and understood by policy makers/advisors (you have not received any feedback from them)", 5], 
         ["Policymakers/advisors reported having difficulties understanding my/our COVID 19 modelling data reports", 11],
         ["My/our group COVID-19 modeling reports were utilized as they were by policy makers/advisors (the evidence you shared was referenced/cited by them as you presented them in policy decisions)", 29],
         ["My/our group COVID-19 modeling reports were not utilized by policy makers/advisors (there was no evidence that your reports informed or influenced policy decisions)", 6],
         ["My/our group COVID-19 modeling reports influenced choices and decisions by policy makers (you received feedback from them about adapting your findings)", 28]]
 
# Create the pandas DataFrame
df7b = pd.DataFrame(data7b, columns=['Prbb', 'q7b'])

# %%
df7b
# Out:
#                                                 Prbb  q7b
# 0  My/our group COVID-19 modeling reports were re...   34
# 1  My/our group COVID-19 modeling reports were no...    5
# 2  Policymakers/advisors reported having difficul...   11
# 3  My/our group COVID-19 modeling reports were ut...   29
# 4  My/our group COVID-19 modeling reports were no...    6
# 5  My/our group COVID-19 modeling reports influen...   28

# %%
df7b['q7b_pct'] = round(((df7b['q7b'] / df7b['q7b'].sum()) * 100),2)
df7b = df7b.set_index('Prbb')

# %%
df7b.to_csv('q7b.csv')

# %%
bx = df7b['q7b_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Knowledge transfer and utilization", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=90)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q7b.png',dpi=400, bbox_inches="tight")

# %%
df['q7c___1'].value_counts()
# Out:
# Unchecked    45
# Checked      24
# Name: q7c___1, dtype: int64

# %%
df['q7c___2'].value_counts()
# Out:
# Unchecked    57
# Checked      12
# Name: q7c___2, dtype: int64

# %%
df['q7c___3'].value_counts()
# Out:
# Unchecked    63
# Checked       6
# Name: q7c___3, dtype: int64

# %%
data7c = [["I have had training on science communication/disseminating my findings to a lay audience", 24], 
         ["My group has a science communicator/engages with science communicators to help communicate our findings to a lay audience", 12], 
         ["Other", 6]]
 
# Create the pandas DataFrame
df7c = pd.DataFrame(data7c, columns=['Prb', 'q7c'])

# %%
df7c.to_csv('q7c.csv')

# %%
df7c['q7c_pct'] = round(((df7c['q7c'] / df7c['q7c'].sum()) * 100),2)
df7c = df7c.set_index('Prb')

# %%
bx = df7c['q7c_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Strategies in place to enhance knowledge transfer", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=90)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q7c.png',dpi=400, bbox_inches="tight")

# %%
df['q8___1'].value_counts()
# Out:
# Unchecked    43
# Checked      26
# Name: q8___1, dtype: int64

# %%
df['q8___2'].value_counts()
# Out:
# Checked      38
# Unchecked    31
# Name: q8___2, dtype: int64

# %%
df['q8___3'].value_counts()
# Out:
# Unchecked    43
# Checked      26
# Name: q8___3, dtype: int64

# %%
df['q8___4'].value_counts()
# Out:
# Unchecked    44
# Checked      25
# Name: q8___4, dtype: int64

# %%
df['q8___5'].value_counts()
# Out:
# Unchecked    60
# Checked       9
# Name: q8___5, dtype: int64

# %%
df['q8___6'].value_counts()
# Out:
# Unchecked    45
# Checked      24
# Name: q8___6, dtype: int64

# %%
df['q8___7'].value_counts()
# Out:
# Unchecked    64
# Checked       5
# Name: q8___7, dtype: int64

# %%
data8 = [["Printed policy briefs/brochures of evidence summaries in lay language", 26], 
         ["Face to face debriefing sessions", 38], 
         ["Evidence summaries posted in group's website/dashboards/blogs", 26],
         ["Email dissemination of evidence summaries", 25],
         ["Using an intermediary/knowledge broker/science communicator to simplify your findings and share with policy makers", 9],
         ["Media briefings of evidence summaries in lay language", 24],
         ["Other", 5]]
 
# Create the pandas DataFrame
df8 = pd.DataFrame(data8, columns=['Prbb', 'q8'])

# %%
df8['q8_pct'] = round(((df8['q8'] / df8['q8'].sum()) * 100),2)
df8 = df8.set_index('Prbb')

# %%
df8.to_csv('q8.csv')

# %%
bx = df8['q8_pct'].plot(kind='bar',figsize=(28,15))


#add overall title
plt.title("Researchers’ methods used to share/disseminate your COVID-19 modeling data outputs with policy makers/advisors", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=90)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q8.png',dpi=400, bbox_inches="tight")

# %%
ff = df['q10'].value_counts().reset_index()
df10 = pd.DataFrame(ff, columns=['index','q10'])
df10['q10_pct'] = round(((df10['q10'] / df10['q10'].sum()) * 100),2)
df10 = df10.set_index('index')

# %%
df10
# Out:
#        q10  q10_pct
# index
# Yes     15     75.0
# No       5     25.0

# %%
bx = df10['q10_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Policymakers’/advisors’ experience receiving COVID-19 modeling data outputs from researchers to aid decision-making process  ", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q10.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
df['q11a___1'].value_counts()
# Out:
# Unchecked    59
# Checked      10
# Name: q11a___1, dtype: int64

# %%
df['q11a___2'].value_counts()
# Out:
# Unchecked    60
# Checked       9
# Name: q11a___2, dtype: int64

# %%
df['q11a___3'].value_counts()
# Out:
# Unchecked    56
# Checked      13
# Name: q11a___3, dtype: int64

# %%
df['q11a___4'].value_counts()
# Out:
# Unchecked    56
# Checked      13
# Name: q11a___4, dtype: int64

# %%
data11a = [["I/we requested COVID-19 modeling data from researchers/modelers to guide the decision making during the pandemic", 10], 
         ["I/we had researchers present their COVID-19 modeling data to us (unsolicited)", 9],
         ["I/we have a pre-existing working relationship with researchers and have been working together to create policy questions and generate evidence for decision-making prior to the pandemic", 13],
         ["I/we have developed a new working relationship with researchers during the pandemic and are now working together to create policy questions and generate evidence for decision-making", 13]]
 
# Create the pandas DataFrame
df11a = pd.DataFrame(data11a, columns=['Prbb', 'q11a'])

# %%
df11a.to_csv('q11a.csv')

# %%
df11a['q11a_pct'] = round(((df11a['q11a'] / df11a['q11a'].sum()) * 100),2)
df11a = df11a.set_index('Prbb')

# %%
bx = df11a['q11a_pct'].plot(kind='bar',figsize=(28,15))


#add overall title
plt.title("Problem identification, knowledge research/development (Policy makers/Advisors)", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=90)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q11a.png',dpi=400, bbox_inches="tight")

# %%
df['q11b___1'].value_counts()
# Out:
# Unchecked    55
# Checked      14
# Name: q11b___1, dtype: int64

# %%
df['q11b___2'].value_counts()
# Out:
# Unchecked    65
# Checked       4
# Name: q11b___2, dtype: int64

# %%
df['q11b___3'].value_counts()
# Out:
# Unchecked    61
# Checked       8
# Name: q11b___3, dtype: int64

# %%
df['q11b___4'].value_counts()
# Out:
# Unchecked    63
# Checked       6
# Name: q11b___4, dtype: int64

# %%
df['q11b___5'].value_counts()
# Out:
# Unchecked    60
# Checked       9
# Name: q11b___5, dtype: int64

# %%
df['q11b___6'].value_counts()
# Out:
# Unchecked    67
# Checked       2
# Name: q11b___6, dtype: int64

# %%
data11b = [["I read and understood information from COVID-19 modeling data reports presented to me", 14], 
         ["I read but had difficulties understanding COVID-19 modeling data reports presented to me", 4],
         ["I/we were utilized COVID-19 modeling reports as they were to guide decision making", 8],
         ["I/we adapted COVID-19 modeling reports form settings similar to ours to guide decision making", 6],
          ["COVID-19 modeling reports influenced my/our choices and decisions related to the pandemic (Specify which ones e.g., epidemiological, scenario forecasts, economic models etc.)",9],
          ["COVID-19 modeling reports did not necessarily influence my/our choices and decisions related to the pandemic", 2]]
 
# Create the pandas DataFrame
df11b = pd.DataFrame(data11b, columns=['Prbb', 'q11b'])

# %%
df11b['q11b_pct'] = round(((df11b['q11b'] / df11b['q11b'].sum()) * 100),2)
df11b = df11b.set_index('Prbb')

# %%
df11b.to_csv('q11b.csv')

# %%
bx = df11b['q11b_pct'].plot(kind='bar',figsize=(28,15))


#add overall title
plt.title("Knowledge transfer and utilization (Policy makers/Advisors) ", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=90)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q11b.png',dpi=400, bbox_inches="tight")

# %%
df['q12___1'].value_counts()
# Out:
# Unchecked    58
# Checked      11
# Name: q12___1, dtype: int64

# %%
df['q12___2'].value_counts()
# Out:
# Unchecked    56
# Checked      13
# Name: q12___2, dtype: int64

# %%
df['q12___3'].value_counts()
# Out:
# Unchecked    59
# Checked      10
# Name: q12___3, dtype: int64

# %%
df['q12___4'].value_counts()
# Out:
# Unchecked    60
# Checked       9
# Name: q12___4, dtype: int64

# %%
df['q12___5'].value_counts()
# Out:
# Unchecked    60
# Checked       9
# Name: q12___5, dtype: int64

# %%
df['q12___6'].value_counts()
# Out:
# Unchecked    61
# Checked       8
# Name: q12___6, dtype: int64

# %%
df['q12___7'].value_counts()
# Out:
# Unchecked    66
# Checked       3
# Name: q12___7, dtype: int64

# %%
data12 = [["Printed policy briefs/brochures of evidence summaries in lay language", 11], 
         ["Face to face debriefing sessions", 13], 
         ["Evidence summaries posted in group's website/dashboards/blogs", 10],
         ["Email dissemination of evidence summaries", 9],
         ["Using an intermediary/knowledge broker/science communicator to simplify your findings and share with policy makers", 9],
         ["Media briefings of evidence summaries in lay language", 8],
         ["Other", 3]]
 
# Create the pandas DataFrame
df12 = pd.DataFrame(data12, columns=['Prbb', 'q12'])

# %%
df12.to_csv('q12.csv')

# %%
df12
# Out:
#                                                 Prbb  q12
# 0  Printed policy briefs/brochures of evidence su...   11
# 1                   Face to face debriefing sessions   13
# 2  Evidence summaries posted in group's website/d...   10
# 3          Email dissemination of evidence summaries    9
# 4  Using an intermediary/knowledge broker/science...    9
# 5  Media briefings of evidence summaries in lay l...    8
# 6                                              Other    3

# %%
df12['q12_pct'] = round(((df12['q12'] / df12['q12'].sum()) * 100),2)
df12 = df12.set_index('Prbb')

# %%
bx = df12['q12_pct'].plot(kind='bar',figsize=(28,15))


#add overall title
plt.title("Respondents’ (policy makers and advisors) preferred methods  to receive COVID-19 modeling data outputs from researchers", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=90)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q12.png',dpi=400, bbox_inches="tight")

# %%
df['ways_for_engagement___1'].value_counts()
# Out:
# Unchecked    47
# Checked      22
# Name: ways_for_engagement___1, dtype: int64

# %%
df['ways_for_engagement___2'].value_counts()
# Out:
# Unchecked    42
# Checked      27
# Name: ways_for_engagement___2, dtype: int64

# %%
df['ways_for_engagement___3'].value_counts()
# Out:
# Unchecked    35
# Checked      34
# Name: ways_for_engagement___3, dtype: int64

# %%
data123 = [["I would like to participate in further in-depth interviews to share more about my experiences", 22], 
         ["I would like to participate in the learning sessions/workshops to help develop better mechanisms for knowledge transfer in LMICs.", 27], 
         ["I would like to receive reports from this work", 34]]
 
# Create the pandas DataFrame
df123 = pd.DataFrame(data123, columns=['Prbb', 'q123'])

# %%
df123.to_csv('q13.csv',index=False)

# %%
df123['q123_pct'] = round(((df123['q123'] / df123['q123'].sum()) * 100),2)
df123 = df123.set_index('Prbb')

# %%
bx = df123['q123_pct'].plot(kind='bar',figsize=(28,15))


#add overall title
plt.title("Indication on the ways in which policy makers/advisors would like to stay engaged", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
#plt.savefig('q7.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
wrap_labels(bx, 10)
bx.figure.savefig('q1232.png',dpi=400, bbox_inches="tight")

# %%
prs = Presentation()
bullet_slide_layout = prs.slide_layouts[0]

slide = prs.slides.add_slide(bullet_slide_layout)
#shapes = slide.shapes

#title_shape = shapes.title
#body_shape = shapes.placeholders[1]

Presentation_Title = slide.placeholders[0]
Presentation_Title.text = "Lessons learned from COVID-19 modeling efforts and impact on policy in lower and middle-income countries (LMICs)"
Presentation_Subtitle = slide.placeholders[1]
Presentation_Subtitle.text = ''

# slide 2 - set the image
img = 'q1.png'

#second_slide = prs.slide_layouts[2]
second_slide = prs.slide_master.slide_layouts[6]

#slide2 = prs.slides.add_slide(second_slide)
#Presentation_Subtitle = slide2.placeholders[1]
#picc = Presentation_Subtitle.insert_picture(img, pptx.util.Inches(0.5), pptx.util.Inches(1.75),
#                              width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#Presentation_Title.text = 'This Is a Test'


slide2 = prs.slides.add_slide(second_slide)
#pic = slide2.shapes.add_picture(img, left= Inches(0.1),top = Inches(0.1), width=None, height=None)
pic = slide2.shapes.add_picture(img, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(9.5), height=pptx.util.Inches(6.5))
#add_picture(image_file, left, top, width=None, height=None)

#slide 3
img2 = 'q2.png'
third_slide = prs.slide_master.slide_layouts[6]
slide3 = prs.slides.add_slide(third_slide)

pic3 = slide3.shapes.add_picture(img2, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 3
img33 = 'q3.png'
third_slide3 = prs.slide_master.slide_layouts[6]
slide33 = prs.slides.add_slide(third_slide3)

pic3 = slide33.shapes.add_picture(img33, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 4
img22 = 'q4.png'
fourth_slide = prs.slide_master.slide_layouts[6]
slide4 = prs.slides.add_slide(fourth_slide)

pic4 = slide4.shapes.add_picture(img22, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))


#slide 5
img3 = 'q5.png'
fifth_slide = prs.slide_master.slide_layouts[6]
slide5 = prs.slides.add_slide(fifth_slide)

pic5 = slide5.shapes.add_picture(img3, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 6
img4 = 'q6.png'
sixth_slide = prs.slide_master.slide_layouts[6]
slide6 = prs.slides.add_slide(sixth_slide)

pic6 = slide6.shapes.add_picture(img4, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 7
img5 = 'q7.png'
s7_slide = prs.slide_master.slide_layouts[6]
slide7 = prs.slides.add_slide(s7_slide)

pic7 = slide7.shapes.add_picture(img5, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 8
img6 = 'q7b.png'
s8_slide = prs.slide_master.slide_layouts[6]
slide8 = prs.slides.add_slide(s8_slide)

pic8 = slide8.shapes.add_picture(img6, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 9
img7 = 'q7c.png'
s9_slide = prs.slide_master.slide_layouts[6]
slide9 = prs.slides.add_slide(s9_slide)

pic9 = slide9.shapes.add_picture(img7, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 10
img8 = 'q8.png'
s10_slide = prs.slide_master.slide_layouts[6]
slide10 = prs.slides.add_slide(s10_slide)

pic10 = slide10.shapes.add_picture(img8, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 11
img9 = 'q10.png'
s11_slide = prs.slide_master.slide_layouts[6]
slide11 = prs.slides.add_slide(s11_slide)

pic11 = slide11.shapes.add_picture(img9, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 12
img10 = 'q11a.png'
s12_slide = prs.slide_master.slide_layouts[6]
slide12 = prs.slides.add_slide(s12_slide)

pic12 = slide12.shapes.add_picture(img10, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 13
img11 = 'q11b.png'
s13_slide = prs.slide_master.slide_layouts[6]
slide13 = prs.slides.add_slide(s13_slide)

pic13 = slide13.shapes.add_picture(img11, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 14
img12 = 'q12.png'
s14_slide = prs.slide_master.slide_layouts[6]
slide14 = prs.slides.add_slide(s14_slide)

pic14 = slide14.shapes.add_picture(img12, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#slide 15
img13 = 'q1232.png'
s15_slide = prs.slide_master.slide_layouts[6]
slide15 = prs.slides.add_slide(s15_slide)

pic15 = slide15.shapes.add_picture(img13, pptx.util.Inches(0), pptx.util.Inches(0.5),
                               width=pptx.util.Inches(10), height=pptx.util.Inches(6))

#prs.save('SONIA Trial Screening Report2.pptx')
prs.save("Preliminary Survey Findings2.pptx")

# %% [markdown]
# ## Subsetting the Dataset into two

# %% [markdown]
# ### Researchers dataset

# %%
df_r = df.loc[(df['q4___1']=='Checked') & (df['q4___2']!='Checked') & (df['q4___3']!='Checked')]

# %%
df_r['q2'].value_counts(sort=False)
# Out:
# 45 - 54yr    13
# 35 - 44yr    16
# 25 - 34yr     6
# ≥65yr         1
# 55 - 64yr     3
# Name: q2, dtype: int64

# %%
df_r.shape
# Out:
# (39, 250)

# %%
g2 = df_r['q1'].value_counts(sort=False).reset_index()
dfg2 = pd.DataFrame(g2, columns=['index','q1'])
dfg2['lang_pct'] = round(((dfg2['q1'] / dfg2['q1'].sum()) * 100),2)
dfg2 = dfg2.set_index('index')
dfg2
# Out:
#         q1  lang_pct
# index
# Male    22     56.41
# Female  17     43.59

# %%
bx2 = dfg2['lang_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Gender of Researchers", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx2.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx2.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q1_r.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
c2 = df_r['q3'].value_counts(sort=False).reset_index()
df33 = pd.DataFrame(c2, columns=['index','q3'])
df33['q3_pct'] = round(((df33['q3'] / df33['q3'].sum()) * 100),2)
df33 = df33.set_index('index')

# %%
df33
# Out:
#                        q3  q3_pct
# index
# Europe                 10   25.64
# Africa                 16   41.03
# Central/South America   3    7.69
# Western Pacific         1    2.56
# North America           2    5.13
# South East Asia         6   15.38
# Eastern Mediterranean   1    2.56

# %%
bx2 = df33['q3_pct'].plot(kind='barh',figsize=(20,10))


#add overall title
plt.title("Researchers' region of work", fontsize=24)

#add axis titles
plt.ylabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
#plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx2.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx2.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(width), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q3_r.png',dpi=400, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Policy makers and Advisers

# %%
df_pa = df.loc[(df['q4___2']=='Checked') | (df['q4___3']=='Checked')]

# %%
df_pa.shape
# Out:
# (21, 250)

# %%
df_pa['q2'].value_counts(sort=False)
# Out:
# 45 - 54yr    7
# 25 - 34yr    5
# 35 - 44yr    7
# 55 - 64yr    2
# Name: q2, dtype: int64

# %%
g3 = df_pa['q1'].value_counts(sort=False).reset_index()
dfg3 = pd.DataFrame(g3, columns=['index','q1'])
dfg3['lang_pct'] = round(((dfg3['q1'] / dfg3['q1'].sum()) * 100),2)
dfg3 = dfg3.set_index('index')
dfg3
# Out:
#         q1  lang_pct
# index
# Male    10     47.62
# Female  10     47.62
# Other    1      4.76

# %%
dfg3
# Out:
#         q1  lang_pct
# index
# Male    10     47.62
# Female  10     47.62
# Other    1      4.76

# %%
bx3 = dfg3['lang_pct'].plot(kind='bar',figsize=(20,10))


#add overall title
plt.title("Gender of Policymakers and Advisors", fontsize=24)

#add axis titles
plt.xlabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
plt.ylabel("Proportion (%)",fontsize=20)
plt.yticks(fontsize=20)

for q in bx3.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx3.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(height), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q1_pa.png',dpi=400, bbox_inches="tight")
plt.show()

# %%
c3 = df_pa['q3'].value_counts(sort=False).reset_index()
df34 = pd.DataFrame(c3, columns=['index','q3'])
df34['q3_pct'] = round(((df34['q3'] / df34['q3'].sum()) * 100),2)
df34 = df34.set_index('index')

# %%
df34
# Out:
#                  q3  q3_pct
# index
# South East Asia   3   14.29
# Africa           13   61.90
# Europe            3   14.29
# North America     2    9.52

# %%
bx3 = df34['q3_pct'].plot(kind='barh',figsize=(20,10))


#add overall title
plt.title("Policymakers and Advisors' region of work", fontsize=24)

#add axis titles
plt.ylabel('',fontsize=20)
plt.xticks(fontsize=20, rotation=0)
#plt.ylabel('Percentage',fontsize=20)
plt.yticks(fontsize=20)

for q in bx3.patches:
    width, height = q.get_width(), q.get_height()
    x, y = q.get_xy() 
    bx3.text(x+width/2, 
            y+height/2, 
            '{:.0f}%'.format(width), 
            horizontalalignment='center', 
            verticalalignment='center',fontsize=20)
    
plt.savefig('q3_pa.png',dpi=400, bbox_inches="tight")
plt.show()
